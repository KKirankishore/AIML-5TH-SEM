# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\Lenovo\\Downloads\\train_and_test2.csv")
print (df)
# Out:
#       Passengerid   Age      Fare  Sex  sibsp  zero  zero.1  zero.2  zero.3  \
# 0               1  22.0    7.2500    0      1     0       0       0       0
# 1               2  38.0   71.2833    1      1     0       0       0       0
# 2               3  26.0    7.9250    1      0     0       0       0       0
# 3               4  35.0   53.1000    1      1     0       0       0       0
# 4               5  35.0    8.0500    0      0     0       0       0       0
# ...           ...   ...       ...  ...    ...   ...     ...     ...     ...
# 1304         1305  28.0    8.0500    0      0     0       0       0       0
# 1305         1306  39.0  108.9000    1      0     0       0       0       0
# 1306         1307  38.5    7.2500    0      0     0       0       0       0
# 1307         1308  28.0    8.0500    0      0     0       0       0       0
# 1308         1309  28.0   22.3583    0      1     0       0       0       0
#
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming the data is in a CSV file named 'data.csv'
# df = pd.read_csv('data.csv')

# Since the data seems to be provided directly, let's create a sample DataFrame
data = {
    'Passengerid': range(1, 1310),
    'Age': [22.0, 38.0, 26.0, 35.0, 35.0] + [28.0] * 1304,
    'Fare': [7.25, 71.2833, 7.925, 53.1, 8.05] + [8.05] * 1304,
    'Sex': [0, 1, 1, 1, 0] + [0] * 1304,
    'sibsp': [1, 1, 0, 1, 0] + [0] * 1304,
    'zero': [0] * 1309,
    'zero.1': [0] * 1309,
    'zero.2': [0] * 1309,
    'zero.3': [0] * 1309,
    'zero.4': [0] * 1309,
    'zero.5': [0] * 1309,
    'zero.6': [0] * 1309,
    'zero.7': [0] * 1309,
    'zero.8': [0] * 1309,
    'zero.9': [0] * 1309,
    'zero.10': [0] * 1309,
    'zero.11': [0] * 1309,
    'zero.12': [0] * 1309,
    'zero.13': [0] * 1309,
    'zero.14': [0] * 1309,
    'Pclass': [3, 1, 3, 1, 3] + [3] * 1304,
    'zero.15': [0] * 1309,
    'zero.16': [0] * 1309,
    'Embarked': [2.0, 0.0, 2.0, 2.0, 2.0] + [2.0] * 1304,
    'zero.17': [0] * 1309,
    'zero.18': [0] * 1309,
    '2urvived': [0, 1, 1, 1, 0] + [0] * 1304
}
df = pd.DataFrame(data)

# Histogram for 'Age'
plt.figure(figsize=(10, 6))
sns.histplot(df['Age'], kde=True, bins=30)
plt.title('Histogram of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# Histogram for 'Fare'
plt.figure(figsize=(10, 6))
sns.histplot(df['Fare'], kde=True, bins=30)
plt.title('Histogram of Fare')
plt.xlabel('Fare')
plt.ylabel('Frequency')
plt.show()
